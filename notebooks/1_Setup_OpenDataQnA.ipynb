# %% [markdown]
# <div style="display: flex; align-items: left;">
#     <a href="https://sites.google.com/corp/google.com/genai-solutions/home?authuser=0">
#         <img src="https://storage.googleapis.com/miscfilespublic/Linkedin%20Banner%20%E2%80%93%202.png" style="margin-right">
#     </a>
# </div>

# %% [markdown]
# <h1 align="center">Open Data QnA - Chat with your SQL Database</h1>
#
# ---
#
# This notebook first walks through the Vector Store Setup needed for running the Open Data QnA application.
#
# Currently supported Source DBs are:
# - PostgreSQL on Google Cloud SQL
# - BigQuery
#
# Furthermore, the following vector stores are supported
# - pgvector on PostgreSQL
# - BigQuery vector
#
#
# The setup part covers the following steps:
# > 1. Configuration: Intial GCP project, IAM permissions, Environment  and Databases setup including logging on Bigquery for analytics
#
# > 2. Creation of Table, Column and Known Good Query Embeddings in the Vector Store  for Retreival Augmented Generation(RAG)
#
#
# Afterwards, you will be able to run the Open Data QnA Pipeline to generate SQL queries and answer questions over your data source.
#
# The pipeline run covers the following steps:
#
# > 1. Take user question and generate sql in the dialect corresponding to data source
#
# > 2. Execute the sql query and retreive the data
#
# > 3. Generate natural language respose and charts to display
#
# > 4. Clean Up resources

# %% [markdown]
# ### 📒 Using this interactive notebook
#
# If you have not used this IDE with jupyter notebooks it will ask for installing Python + Jupyter extensions. Please go ahead install them
#
# Click the **run** icons ▶️  of each cell within this notebook.
#
# > 💡 Alternatively, you can run the currently selected cell with `Ctrl + Enter` (or `⌘ + Enter` on a Mac).
#
# > ⚠️ **To avoid any errors**, wait for each section to finish in their order before clicking the next “run” icon.
#
# This sample must be connected to a **Google Cloud project**, but nothing else is needed other than your Google Cloud project.
#
# You can use an existing project. Alternatively, you can create a new Cloud project [with cloud credits for free.](https://cloud.google.com/free/docs/gcp-free-tier)

# %% [markdown]
# # 🚧 **0. Prerequisites**
#
# Make sure that Google Cloud CLI is installed before moving to the next cell! You can refer to the link below for guidance
#
# Installation Guide: https://cloud.google.com/sdk/docs/install

# %% [markdown]
# ### Set Python Module Path to Root

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport

import logging
format_string = '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='mylog.log', mode='a')
formatter = logging.Formatter(format_string)
fhandler.setFormatter(formatter)
#logger.addHandler(fhandler)
logging.basicConfig(format=format_string,
                     level=logging.INFO, stream=sys.stdout)
logger.setLevel(logging.INFO)
# Out:
# Modules to reload:
# all-except-skipped
#
# Modules to skip:

# %% [markdown]
# ### 🔗 **Connect Your Google Cloud Project**
# Time to connect your Google Cloud Project to this notebook.

# %%
#@markdown Please fill in the value below with your GCP project ID and then run the cell.
PROJECT_ID = "uk-bh-experiments-argolis"

# Quick input validations.
assert PROJECT_ID, "⚠️ Please provide your Google Cloud Project ID"

# Configure gcloud.
# !gcloud config set project {PROJECT_ID}
print(f'Project has been set to {PROJECT_ID}')

os.environ['GOOGLE_CLOUD_QUOTA_PROJECT']=PROJECT_ID
os.environ['GOOGLE_CLOUD_PROJECT']=PROJECT_ID
# Out:
# Updated property [core/project].
# Project has been set to uk-bh-experiments-argolis

# %% [markdown]
# ### 🤔 **Choose Data Source and Vector Store**

# %% [markdown]
# Fill out the parameters and configuration settings below.
# These are the parameters for connecting to the source databases and setting configurations for the vector store tables to be created.
# Additionally, you can specify whether you have and want to use known-good-queries for the pipeline run and whether you want to enable logging.
#
# **Known good queries:** if you have known working user question <-> SQL query pairs, you can put them into the file `scripts/known_good_sql.csv`. This will be used as a caching layer and for in-context learning: If an exact match of the user question is found in the vector store, the pipeline will skip SQL Generation and output the cached SQL query. If the similarity score is between 90-100%, the known good queries will be used as few-shot examples by the SQL Generator Agent.
#
# **Logging:** you can enable logging. If enabled, a dataset is created in Big Query in your project, which will store the logging table and save information from the pipeline run in the logging table. This is especially helpful for debugging.

# %%
#[CONFIG]
embedding_model = 'vertex' # Options: 'vertex' or 'vertex-lang'
vector_embedding_model = "text-embedding-004"
description_model = 'gemini-1.5-pro-001' # 'gemini-1.5-pro-001', 'gemini-1.5-pro', 'text-bison-32k'
data_source = 'bigquery' #  Options: 'bigquery' and 'cloudsql-pg' 
vector_store = 'bigquery-vector' # Options: 'bigquery-vector', 'cloudsql-pgvector'
logging = True # True or False 
kgq_examples = True # True or False 

#[GCP]
project_id = PROJECT_ID

#[PGCLOUDSQL]
# If you want to use PG as source, fill out the values below
pg_region = ''
pg_instance = ''
pg_database = ''
pg_user = ''
pg_password = ''
pg_schema = ''

#[BIGQUERY]
# If you want to use BQ as source, fill out the values below
bq_dataset_region = 'us-east11'
bq_dataset_name = 'breedr'

# Name for the BQ dataset created for bigquery-vector and/or logging
bq_opendataqna_dataset_name = 'opendataqna'
bq_log_table_name = 'audit_log_table' 
bq_table_list = None # ["animal_breeds", "activity_types", "alert_type", "activity_types"]  # either None or a list of table names in format ['reviews', 'ratings']

#Decode Region and Userdatabase based on source
if data_source == 'bigquery': dataset_region = bq_dataset_region; user_database=bq_dataset_name 
elif data_source == 'cloudsql-pg': dataset_region = pg_region; user_database=pg_schema

# %% [markdown]
# Quick input verifications below:

# %%
# Input verification - Source
assert data_source in {'bigquery', 'cloudsql-pg'}, "⚠️ Invalid DATA_SOURCE. Must be 'bigquery' or 'cloudsql-pg'"

# Input verification - Vector Store
assert vector_store in {'bigquery-vector', 'cloudsql-pgvector'}, "⚠️ Invalid VECTOR_STORE. Must be 'bigquery-vector' or 'cloudsql-pgvector'"

if logging: 
    assert bq_log_table_name, "⚠️ Please provide a name for your log table if you want to use logging"

if data_source == 'bigquery':
    assert bq_dataset_region, "⚠️ Please provide the Data Set Region"
    assert bq_dataset_name, "⚠️ Please provide the name of the dataset on Bigquery"

elif data_source == 'cloudsql-pg':
    assert pg_region, "⚠️ Please provide Region of the Cloud SQL Instance"
    assert pg_instance, "⚠️ Please provide the name of the Cloud SQL Instance"
    assert pg_database, "⚠️ Please provide the name of the PostgreSQL Database on the Cloud SQL Instance"
    assert pg_user, "⚠️ Please provide a username for the Cloud SQL Instance"
    assert pg_password, "⚠️ Please provide the Password for the PG_USER"

# %% [markdown]
# ### 💾 **Save Configuration to File**
# Save the configurations set in this notebook to  `config.ini`. The parameters from this file are used in notebooks and in various modeules in the repo

# %%
from scripts import save_config

save_config(embedding_model, vector_embedding_model, description_model, data_source, vector_store, logging, kgq_examples, PROJECT_ID,
            pg_region, pg_instance, pg_database, pg_user, pg_password, pg_schema, 
            bq_dataset_region, bq_dataset_name, 
            bq_opendataqna_dataset_name, bq_log_table_name, bq_table_list)
# Out:
# current dir:  /home/jupyter/uk-bh-experiments/bhfork-opendataqna/applied-ai-engineering-samples/notebooks
# All configuration paramaters saved to file!

# %% [markdown]
# ##  **1.2. Create Embeddings in Vector Store for RAG**

# %% [markdown]
# ### 🖋️ **Create Table and Column Embeddings**
#
# In this step, table and column metadata is retreived from the data source and embeddings are generated for both

# %%
from env_setup import get_embeddings

# Generate embeddings for tables and columns
table_schema_embeddings, col_schema_embeddings = get_embeddings()
# Out:
# current dir:  /home/jupyter/uk-bh-experiments/bhfork-opendataqna/applied-ai-engineering-samples/notebooks
# root_dir set to: /home/jupyter/uk-bh-experiments/bhfork-opendataqna/applied-ai-engineering-samples
# 2024-06-26 11:03:02,335 - agents.core - INFO - LLM Model is gemini-1.5-pro-001
# Generating embeddings from source db schemas
# 2024-06-26 11:03:04,815 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.business_units
# 2024-06-26 11:03:06,860 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.cts_dairy_breeds
# 2024-06-26 11:03:08,141 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit
# 2024-06-26 11:03:09,512 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.supply_chain
# 2024-06-26 11:03:10,722 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_vmd_data
# 2024-06-26 11:03:12,050 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_identifierassignment
# 2024-06-26 11:03:13,652 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animal_types
# 2024-06-26 11:03:15,046 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_lineitem
# 2024-06-26 11:03:16,452 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.predictions_when_weighed
# 2024-06-26 11:03:17,733 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.countries
# 2024-06-26 11:03:18,905 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_tag_change
# 2024-06-26 11:03:20,465 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.lots
# 2024-06-26 11:03:22,729 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_identifierpreferences
# 2024-06-26 11:03:24,130 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.kill_information
# 2024-06-26 11:03:25,522 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals
# 2024-06-26 11:03:27,139 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_tag_value
# 2024-06-26 11:03:28,654 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.currencies
# 2024-06-26 11:03:29,707 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_stockitem_species
# 2024-06-26 11:03:30,662 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_withdrawals
# 2024-06-26 11:03:32,178 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.crush_app_sessions
# 2024-06-26 11:03:33,974 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.activity_types
# 2024-06-26 11:03:35,355 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals2
# 2024-06-26 11:03:37,085 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.groups
# 2024-06-26 11:03:38,368 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.pasture_types
# 2024-06-26 11:03:39,358 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.business_unit_users
# 2024-06-26 11:03:40,398 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_tag
# 2024-06-26 11:03:42,009 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.organizations_organisation
# 2024-06-26 11:03:43,412 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_itemtransaction
# 2024-06-26 11:03:44,705 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicine_stockitem
# 2024-06-26 11:03:45,938 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.medicines
# 2024-06-26 11:03:47,055 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.offers
# 2024-06-26 11:03:48,208 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.supply_chain_member
# 2024-06-26 11:03:49,523 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.group_reports
# 2024-06-26 11:03:50,965 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.activities
# 2024-06-26 11:03:52,700 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animals_animal_breeds
# 2024-06-26 11:03:53,812 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.reports_business_types
# 2024-06-26 11:03:55,127 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.business_types
# 2024-06-26 11:03:56,739 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.animal_breeds
# 2024-06-26 11:03:57,723 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.alert_type
# 2024-06-26 11:03:59,309 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.fields
# 2024-06-26 11:04:01,113 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.activity_templates
# 2024-06-26 11:04:02,576 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.account_user
# 2024-06-26 11:04:03,893 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.crush_app_sessions_animals
# 2024-06-26 11:04:05,198 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.fields_pasture_types
# 2024-06-26 11:04:06,475 - agents.DescriptionAgent - INFO - Generate description for table uk-bh-experiments-argolis.breedr.weights
#
# LLM generated 45 Table Descriptions
# 2024-06-26 11:04:08,322 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_0
# 2024-06-26 11:04:09,553 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_1
# 2024-06-26 11:04:10,955 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_10
# 2024-06-26 11:04:12,046 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_11
# 2024-06-26 11:04:12,986 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_12
# 2024-06-26 11:04:14,165 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_13
# 2024-06-26 11:04:15,258 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_14
# 2024-06-26 11:04:16,518 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_15
# 2024-06-26 11:04:17,812 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_16
# 2024-06-26 11:04:19,070 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_17
# 2024-06-26 11:04:20,232 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_18
# 2024-06-26 11:04:21,367 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_19
# 2024-06-26 11:04:22,650 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_2
# 2024-06-26 11:04:23,874 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_20
# 2024-06-26 11:04:24,984 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_21
# 2024-06-26 11:04:26,045 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_22
# 2024-06-26 11:04:27,460 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_23
# 2024-06-26 11:04:28,756 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_24
# 2024-06-26 11:04:30,367 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_25
# 2024-06-26 11:04:31,729 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_26
# 2024-06-26 11:04:33,097 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_27
# 2024-06-26 11:04:34,402 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_28
# 2024-06-26 11:04:35,615 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_29
# 2024-06-26 11:04:36,881 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_3
# 2024-06-26 11:04:38,148 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_4
# 2024-06-26 11:04:39,315 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_5
# 2024-06-26 11:04:40,416 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_6
# 2024-06-26 11:04:41,486 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_7
# 2024-06-26 11:04:42,629 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_8
# 2024-06-26 11:04:43,736 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.account_user.string_field_9
# 2024-06-26 11:04:44,761 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.activity_template_id
# 2024-06-26 11:04:45,990 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.activity_type_id
# 2024-06-26 11:04:47,142 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.animal_id
# 2024-06-26 11:04:48,192 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.batch_id
# 2024-06-26 11:04:49,349 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.business_unit_id
# 2024-06-26 11:04:50,415 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.created_at
# 2024-06-26 11:04:51,859 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.created_by_id
# 2024-06-26 11:04:52,915 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.date
# 2024-06-26 11:04:54,180 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.fields
# 2024-06-26 11:04:55,519 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.groups
# 2024-06-26 11:04:56,657 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.id
# 2024-06-26 11:04:57,741 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.is_copied
# 2024-06-26 11:04:58,697 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.payload
# 2024-06-26 11:04:59,800 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.unique_hash
# 2024-06-26 11:05:00,862 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activities.updated_at
# 2024-06-26 11:05:02,239 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.activity_type_id
# 2024-06-26 11:05:03,519 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.allow_repeat_activity
# 2024-06-26 11:05:04,872 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.business_unit_id
# 2024-06-26 11:05:05,920 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.created_by_id
# 2024-06-26 11:05:07,353 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.handlers
# 2024-06-26 11:05:08,830 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.id
# 2024-06-26 11:05:09,765 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.is_allowed_to_delete
# 2024-06-26 11:05:10,872 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.is_batchable
# 2024-06-26 11:05:12,031 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.is_disabled
# 2024-06-26 11:05:13,114 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.is_public
# 2024-06-26 11:05:14,312 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.is_system
# 2024-06-26 11:05:15,398 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.long_description
# 2024-06-26 11:05:16,342 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.name
# 2024-06-26 11:05:17,399 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.short_description
# 2024-06-26 11:05:18,667 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.slug
# 2024-06-26 11:05:19,818 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_templates.value_description
# 2024-06-26 11:05:21,209 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.id
# 2024-06-26 11:05:22,173 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.image
# 2024-06-26 11:05:23,319 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.image_svg
# 2024-06-26 11:05:24,749 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.is_copyable
# 2024-06-26 11:05:26,182 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.is_extendable
# 2024-06-26 11:05:27,587 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.is_public
# 2024-06-26 11:05:28,841 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.is_system
# 2024-06-26 11:05:29,856 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.name
# 2024-06-26 11:05:31,321 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.position
# 2024-06-26 11:05:32,239 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.activity_types.slug
# 2024-06-26 11:05:33,419 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.alert_type.code
# 2024-06-26 11:05:34,566 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.alert_type.disabled
# 2024-06-26 11:05:35,637 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.alert_type.name
# 2024-06-26 11:05:36,885 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.alert_type.object_type
# 2024-06-26 11:05:38,352 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.animal_type_id
# 2024-06-26 11:05:39,567 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.birth_weight
# 2024-06-26 11:05:40,549 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.breedr_code
# 2024-06-26 11:05:42,028 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.classification
# 2024-06-26 11:05:43,200 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.id
# 2024-06-26 11:05:44,391 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.is_obsolete
# 2024-06-26 11:05:45,563 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.name
# 2024-06-26 11:05:46,991 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.new_classification
# 2024-06-26 11:05:48,015 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.reg_breed_code
# 2024-06-26 11:05:49,335 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.reg_name
# 2024-06-26 11:05:50,334 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.region_id
# 2024-06-26 11:05:51,290 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_breeds.version
# 2024-06-26 11:05:52,271 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.batch_name
# 2024-06-26 11:05:53,711 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.colour
# 2024-06-26 11:05:54,593 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.enabled
# 2024-06-26 11:05:55,656 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.enabled_predictions
# 2024-06-26 11:05:56,953 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.gestation_days
# 2024-06-26 11:05:58,293 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.id
# 2024-06-26 11:05:59,565 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.image
# 2024-06-26 11:06:01,058 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.name
# 2024-06-26 11:06:02,196 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.position
# 2024-06-26 11:06:03,340 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animal_types.slug
# 2024-06-26 11:06:04,526 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.animal_colour_id
# 2024-06-26 11:06:06,089 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.animal_subtype
# 2024-06-26 11:06:07,415 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.animal_type_id
# 2024-06-26 11:06:08,774 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.birth_information_id
# 2024-06-26 11:06:10,436 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.breed_society_registration
# 2024-06-26 11:06:11,749 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.breeding
# 2024-06-26 11:06:12,956 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.children
# 2024-06-26 11:06:14,264 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.created_at
# 2024-06-26 11:06:15,402 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.dam_id
# 2024-06-26 11:06:16,760 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.dam_passport_number
# 2024-06-26 11:06:18,132 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.dam_passport_number_cleaned
# 2024-06-26 11:06:19,815 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.date_left_farm
# 2024-06-26 11:06:21,368 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.date_moved_to_farm
# 2024-06-26 11:06:22,913 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.dead_at
# 2024-06-26 11:06:24,073 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.description
# 2024-06-26 11:06:25,203 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.dob
# 2024-06-26 11:06:26,509 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.e_id
# 2024-06-26 11:06:27,868 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.e_id_cleaned
# 2024-06-26 11:06:29,329 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.e_ids_history
# 2024-06-26 11:06:30,932 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.field_id
# 2024-06-26 11:06:32,105 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.group_id
# 2024-06-26 11:06:33,274 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.id
# 2024-06-26 11:06:34,500 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.impact_status
# 2024-06-26 11:06:35,820 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_birthed
# 2024-06-26 11:06:36,718 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_castrated
# 2024-06-26 11:06:38,019 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_male
# 2024-06-26 11:06:39,076 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_on_farm
# 2024-06-26 11:06:40,251 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_owned_by_impact
# 2024-06-26 11:06:41,282 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_pedigree
# 2024-06-26 11:06:42,325 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_pregnant
# 2024-06-26 11:06:43,367 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_regulatory_synced
# 2024-06-26 11:06:45,044 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.is_soft_deleted
# 2024-06-26 11:06:46,385 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.kill_fat_score
# 2024-06-26 11:06:47,935 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.kill_fat_score_int
# 2024-06-26 11:06:49,790 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.kill_quality
# 2024-06-26 11:06:50,942 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.kill_quality_int
# 2024-06-26 11:06:52,087 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.kill_weight
# 2024-06-26 11:06:53,317 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.last_regulatory_synced_date
# 2024-06-26 11:06:54,850 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.link_to_my_sire_id
# 2024-06-26 11:06:56,439 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.link_to_origin_animal_id
# 2024-06-26 11:06:58,292 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.location_id
# 2024-06-26 11:06:59,475 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.lot_id
# 2024-06-26 11:07:00,895 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.meta_data
# 2024-06-26 11:07:02,167 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.name
# 2024-06-26 11:07:03,242 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.owner_id
# 2024-06-26 11:07:04,654 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.owners_history
# 2024-06-26 11:07:06,003 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.passport_number
# 2024-06-26 11:07:07,031 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.passport_number_cleaned
# 2024-06-26 11:07:08,526 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.pedigree
# 2024-06-26 11:07:09,705 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.pregnancy_due_date
# 2024-06-26 11:07:10,912 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.registration_status
# 2024-06-26 11:07:12,025 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.related_meat_labels
# 2024-06-26 11:07:13,467 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.sire_id
# 2024-06-26 11:07:14,825 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.sire_is_pedigree
# 2024-06-26 11:07:16,474 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.sire_passport_number
# 2024-06-26 11:07:17,682 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.sire_passport_number_cleaned
# 2024-06-26 11:07:19,133 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.sire_studs
# 2024-06-26 11:07:20,658 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.soft_deleted_at
# 2024-06-26 11:07:22,194 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.stud_sired_id
# 2024-06-26 11:07:23,717 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.updated_at
# 2024-06-26 11:07:24,833 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.updated_by_id
# 2024-06-26 11:07:26,217 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.visual_id
# 2024-06-26 11:07:27,376 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals.visual_ids_history
# 2024-06-26 11:07:28,594 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.animal_colour_id
# 2024-06-26 11:07:29,829 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.animal_subtype
# 2024-06-26 11:07:31,276 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.animal_type_id
# 2024-06-26 11:07:32,937 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.birth_information_id
# 2024-06-26 11:07:34,216 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.breed_society_registration
# 2024-06-26 11:07:35,311 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.breeding
# 2024-06-26 11:07:36,308 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.children
# 2024-06-26 11:07:37,873 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.created_at
# 2024-06-26 11:07:39,474 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.dam_id
# 2024-06-26 11:07:41,054 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.dam_passport_number
# 2024-06-26 11:07:42,222 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.dam_passport_number_cleaned
# 2024-06-26 11:07:43,632 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.date_left_farm
# 2024-06-26 11:07:44,739 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.date_moved_to_farm
# 2024-06-26 11:07:46,080 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.dead_at
# 2024-06-26 11:07:47,355 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.description
# 2024-06-26 11:07:48,654 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.dob
# 2024-06-26 11:07:49,955 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.e_id
# 2024-06-26 11:07:51,299 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.e_id_cleaned
# 2024-06-26 11:07:53,208 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.e_ids_history
# 2024-06-26 11:07:54,879 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.field_id
# 2024-06-26 11:07:56,082 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.group_id
# 2024-06-26 11:07:57,330 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.id
# 2024-06-26 11:07:58,576 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.impact_status
# 2024-06-26 11:08:00,680 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_birthed
# 2024-06-26 11:08:01,953 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_castrated
# 2024-06-26 11:08:02,931 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_male
# 2024-06-26 11:08:03,770 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_on_farm
# 2024-06-26 11:08:05,091 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_owned_by_impact
# 2024-06-26 11:08:06,170 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_pedigree
# 2024-06-26 11:08:07,267 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_pregnant
# 2024-06-26 11:08:08,731 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_regulatory_synced
# 2024-06-26 11:08:10,467 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.is_soft_deleted
# 2024-06-26 11:08:11,809 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.kill_fat_score
# 2024-06-26 11:08:13,548 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.kill_fat_score_int
# 2024-06-26 11:08:14,919 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.kill_quality
# 2024-06-26 11:08:16,343 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.kill_quality_int
# 2024-06-26 11:08:17,686 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.kill_weight
# 2024-06-26 11:08:18,930 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.last_regulatory_synced_date
# 2024-06-26 11:08:20,610 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.link_to_my_sire_id
# 2024-06-26 11:08:22,211 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.link_to_origin_animal_id
# 2024-06-26 11:08:23,772 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.location_id
# 2024-06-26 11:08:25,084 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.lot_id
# 2024-06-26 11:08:26,685 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.meta_data
# 2024-06-26 11:08:27,906 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.name
# 2024-06-26 11:08:29,658 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.owner_id
# 2024-06-26 11:08:30,843 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.owners_history
# 2024-06-26 11:08:33,021 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.passport_number
# 2024-06-26 11:08:34,357 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.passport_number_cleaned
# 2024-06-26 11:08:35,608 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.pedigree
# 2024-06-26 11:08:36,809 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.pregnancy_due_date
# 2024-06-26 11:08:38,197 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.registration_status
# 2024-06-26 11:08:39,388 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.related_meat_labels
# 2024-06-26 11:08:40,554 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.sire_id
# 2024-06-26 11:08:42,100 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.sire_is_pedigree
# 2024-06-26 11:08:43,617 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.sire_passport_number
# 2024-06-26 11:08:44,789 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.sire_passport_number_cleaned
# 2024-06-26 11:08:46,184 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.sire_studs
# 2024-06-26 11:08:47,332 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.soft_deleted_at
# 2024-06-26 11:08:48,655 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.stud_sired_id
# 2024-06-26 11:08:50,418 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.updated_at
# 2024-06-26 11:08:52,321 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.updated_by_id
# 2024-06-26 11:08:54,043 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.visual_id
# 2024-06-26 11:08:55,379 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals2.visual_ids_history
# 2024-06-26 11:08:56,637 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_animal_breeds.animal_id
# 2024-06-26 11:08:57,512 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_animal_breeds.animalbreed_id
# 2024-06-26 11:08:58,629 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_animal_breeds.id
# 2024-06-26 11:08:59,661 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_animal_breeds.percentage
# 2024-06-26 11:09:00,929 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.alternative_id
# 2024-06-26 11:09:02,210 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.animal_id
# 2024-06-26 11:09:03,559 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.breedr_id
# 2024-06-26 11:09:04,853 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.brucellosis_id
# 2024-06-26 11:09:06,185 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.herd_dogg_id
# 2024-06-26 11:09:07,795 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.pedigree_id
# 2024-06-26 11:09:09,243 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.tattoo
# 2024-06-26 11:09:10,510 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.trich_id
# 2024-06-26 11:09:11,921 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.tsu_barcode
# 2024-06-26 11:09:13,078 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierassignment.uhf_id
# 2024-06-26 11:09:14,560 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.alternative_id
# 2024-06-26 11:09:15,868 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.breedr_id
# 2024-06-26 11:09:17,220 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.brucellosis_id
# 2024-06-26 11:09:18,493 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.business_unit_id
# 2024-06-26 11:09:20,194 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.e_id
# 2024-06-26 11:09:21,413 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.herd_dogg_id
# 2024-06-26 11:09:22,513 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.id
# 2024-06-26 11:09:23,576 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.name
# 2024-06-26 11:09:25,096 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.passport_number
# 2024-06-26 11:09:26,493 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.pedigree_id
# 2024-06-26 11:09:27,705 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.primary_id
# 2024-06-26 11:09:28,871 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.secondary_id
# 2024-06-26 11:09:30,122 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.tattoo
# 2024-06-26 11:09:31,113 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.trich_id
# 2024-06-26 11:09:32,470 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.tsu_barcode
# 2024-06-26 11:09:34,109 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.uhf_id
# 2024-06-26 11:09:35,389 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.updated_at
# 2024-06-26 11:09:36,597 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.user_id
# 2024-06-26 11:09:37,943 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_identifierpreferences.visual_id
# 2024-06-26 11:09:39,106 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.color
# 2024-06-26 11:09:40,151 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.created_at
# 2024-06-26 11:09:41,171 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.deactivated_at
# 2024-06-26 11:09:42,361 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.id
# 2024-06-26 11:09:43,637 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.is_active
# 2024-06-26 11:09:44,818 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.is_lifetime
# 2024-06-26 11:09:45,784 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.is_removable
# 2024-06-26 11:09:46,910 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.is_system
# 2024-06-26 11:09:48,175 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.name
# 2024-06-26 11:09:49,524 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.owner_id
# 2024-06-26 11:09:50,537 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.reporting_code
# 2024-06-26 11:09:51,850 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.slug
# 2024-06-26 11:09:53,126 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.text_color
# 2024-06-26 11:09:54,553 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.updated_at
# 2024-06-26 11:09:55,734 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.animals_tag.value_type
# ...
# 2024-06-26 11:15:28,338 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_stockitem_species.id
# 2024-06-26 11:15:29,315 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_stockitem_species.stockitem_id
# 2024-06-26 11:15:30,606 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.active_substances
# 2024-06-26 11:15:31,582 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.antibiotic_active_ingredient_mg_unit
# 2024-06-26 11:15:33,084 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.antibiotic_active_ingredient_unit
# 2024-06-26 11:15:34,267 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.antibiotic_class
# 2024-06-26 11:15:35,184 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.antibiotic_route_of_administration
# 2024-06-26 11:15:36,325 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.distribution_category
# 2024-06-26 11:15:37,554 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.hp_cia
# 2024-06-26 11:15:38,927 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.id
# 2024-06-26 11:15:40,120 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.pharmaceutical_form
# 2024-06-26 11:15:41,295 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.product_name
# 2024-06-26 11:15:42,465 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.target_species
# 2024-06-26 11:15:43,914 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.therapeutic_group
# 2024-06-26 11:15:45,134 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_vmd_data.vm_number
# 2024-06-26 11:15:46,412 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.animal_type_id
# 2024-06-26 11:15:47,437 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.id
# 2024-06-26 11:15:48,681 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.medicine_id
# 2024-06-26 11:15:49,799 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.notes
# 2024-06-26 11:15:50,827 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.use_withdrawal_period
# 2024-06-26 11:15:51,857 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.withdrawal_period_days
# 2024-06-26 11:15:53,502 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicine_withdrawals.withdrawal_type
# 2024-06-26 11:15:54,490 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.active_ingredient_id
# 2024-06-26 11:15:55,792 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.application_method_id
# 2024-06-26 11:15:57,159 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.barcode
# 2024-06-26 11:15:58,240 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.bottle_sizes
# 2024-06-26 11:15:59,382 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.common_name
# 2024-06-26 11:16:00,759 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.created_at
# 2024-06-26 11:16:02,100 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.description
# 2024-06-26 11:16:03,136 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.id
# 2024-06-26 11:16:04,137 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.is_disabled
# 2024-06-26 11:16:05,449 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.link
# 2024-06-26 11:16:06,761 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.man_name
# 2024-06-26 11:16:08,109 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.manufacturer
# 2024-06-26 11:16:09,434 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.noah_id
# 2024-06-26 11:16:10,795 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.updated_at
# 2024-06-26 11:16:12,197 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.medicines.vmd_data_id
# 2024-06-26 11:16:13,786 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.business_unit_id
# 2024-06-26 11:16:14,895 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.collection_date
# 2024-06-26 11:16:16,123 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.comment
# 2024-06-26 11:16:17,392 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.created_at
# 2024-06-26 11:16:18,977 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.created_by_id
# 2024-06-26 11:16:20,314 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.currency_id
# 2024-06-26 11:16:21,461 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.entity_id
# 2024-06-26 11:16:22,930 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.entity_type_id
# 2024-06-26 11:16:24,464 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.has_accepted_listing
# 2024-06-26 11:16:25,549 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.id
# 2024-06-26 11:16:26,485 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.offered_number
# 2024-06-26 11:16:27,771 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.price
# 2024-06-26 11:16:29,060 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.price_unit
# 2024-06-26 11:16:30,283 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.produced_lot_id
# 2024-06-26 11:16:31,611 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.response_date
# 2024-06-26 11:16:32,889 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.status
# 2024-06-26 11:16:34,139 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.tac_accept_record_id
# 2024-06-26 11:16:35,872 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.to_lot_id
# 2024-06-26 11:16:37,456 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.to_want_id
# 2024-06-26 11:16:38,610 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.total_price_on_creation
# 2024-06-26 11:16:39,708 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.offers.updated_at
# 2024-06-26 11:16:41,041 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.business_type_id
# 2024-06-26 11:16:42,230 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.country_id
# 2024-06-26 11:16:43,259 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.currency_id
# 2024-06-26 11:16:44,304 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.id
# 2024-06-26 11:16:45,730 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.name
# 2024-06-26 11:16:46,810 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.number_of_farms
# 2024-06-26 11:16:48,196 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.organizations_organisation.owner_id
# 2024-06-26 11:16:49,198 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.pasture_types.id
# 2024-06-26 11:16:50,353 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.pasture_types.name
# 2024-06-26 11:16:51,274 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.animal_id
# 2024-06-26 11:16:52,496 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.date
# 2024-06-26 11:16:53,653 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.dlwg
# 2024-06-26 11:16:55,204 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.id
# 2024-06-26 11:16:56,425 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.last_date
# 2024-06-26 11:16:57,471 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.last_weight
# 2024-06-26 11:16:58,408 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.predicted_weight_at_date
# 2024-06-26 11:16:59,838 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.predictions_when_weighed.weight
# 2024-06-26 11:17:00,891 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.reports_business_types.businesstype_id
# 2024-06-26 11:17:02,283 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.reports_business_types.id
# 2024-06-26 11:17:03,299 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.reports_business_types.report_id
# 2024-06-26 11:17:04,780 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain.controller_business_unit_id
# 2024-06-26 11:17:06,380 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain.id
# 2024-06-26 11:17:07,541 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain.name
# 2024-06-26 11:17:08,754 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain.ownership_tag_id
# 2024-06-26 11:17:09,919 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain_member.business_unit_id
# 2024-06-26 11:17:11,318 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain_member.id
# 2024-06-26 11:17:12,302 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain_member.is_active
# 2024-06-26 11:17:13,427 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain_member.modified_at
# 2024-06-26 11:17:14,706 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.supply_chain_member.supply_chain_id
# 2024-06-26 11:17:16,055 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit.business_unit_id
# 2024-06-26 11:17:17,549 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit.code
# 2024-06-26 11:17:18,777 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit.id
# 2024-06-26 11:17:19,816 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit.long_description
# 2024-06-26 11:17:21,231 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.unit_of_measurement_business_unit.measurement_type
# 2024-06-26 11:17:23,008 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.age
# 2024-06-26 11:17:24,251 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.animal_id
# 2024-06-26 11:17:25,060 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.batch_id
# 2024-06-26 11:17:26,375 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.business_unit_id
# 2024-06-26 11:17:27,851 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.created_at
# 2024-06-26 11:17:29,374 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.current_date
# 2024-06-26 11:17:30,408 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.dlwg
# 2024-06-26 11:17:31,816 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.id
# 2024-06-26 11:17:32,917 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.updated_at
# 2024-06-26 11:17:34,457 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.weight_type
# 2024-06-26 11:17:35,486 - agents.DescriptionAgent - INFO - Generate description for column  uk-bh-experiments-argolis.breedr.weights.weight_value
#
# LLM generated 631 Column Descriptions
# Table and Column embeddings are created

# %%
table_schema_embeddings.describe()
# Out:
#        table_schema      table_name  \
# count            45              45
# unique            1              45
# top          breedr  business_units
# freq             45               1
#
#                                                   content  \
# count                                                  45
# unique                                                 45
# top     \n            Full Table Name : uk-bh-experime...
# freq                                                    1
#
#                                                 embedding
# count                                                  45
# unique                                                 45
# top     [0.022505661472678185, 0.028678087517619133, -...
# freq                                                    1

# %%
col_schema_embeddings.describe()
# Out:
#        table_schema table_name column_name  \
# count           631        631         631
# unique            1         45         374
# top          breedr    animals          id
# freq            631         63          41
#
#                                                   content  \
# count                                                 631
# unique                                                631
# top     \n            Column Name: breedr.account_user...
# freq                                                    1
#
#                                                 embedding
# count                                                 631
# unique                                                631
# top     [0.0012524769408628345, 0.07620758563280106, -...
# freq                                                    1

# %% [markdown]
# ### 💾 **Save the Table and Column Embeddings in the Vector Store**
# The table and column embeddings created in the above step are save to the Vector Store chosen

# %%
from env_setup import store_embeddings


# Store table/column embeddings (asynchronous)
await(store_embeddings(table_schema_embeddings, col_schema_embeddings))
# Out:
# Storing embeddings back to the vector store.
# 2024-06-26 11:18:15,144 - embeddings.store_embeddings - INFO - Clean up table_details_embeddings: query_string=" DELETE FROM `uk-bh-experiments-argolis.opendataqna.table_details_embeddings` WHERE table_schema = 'breedr' AND table_name IN( 'business_units','cts_dairy_breeds','unit_of_measurement_business_unit','supply_chain','medicine_vmd_data','animals_identifierassignment','animal_types','medicine_lineitem','predictions_when_weighed','countries','animals_tag_change','lots','animals_identifierpreferences','kill_information','animals','animals_tag_value','currencies','medicine_stockitem_species','medicine_withdrawals','crush_app_sessions','activity_types','animals2','groups','pasture_types','business_unit_users','animals_tag','organizations_organisation','medicine_itemtransaction','medicine_stockitem','medicines','offers','supply_chain_member','group_reports','activities','animals_animal_breeds','reports_business_types','business_types','animal_breeds','alert_type','fields','activity_templates','account_user','crush_app_sessions_animals','fields_pasture_types','weights' )"
# 2024-06-26 11:18:17,441 - embeddings.store_embeddings - INFO - Storing table embeddings to BQ uk-bh-experiments-argolis.opendataqna.table_details_embeddings'
# 2024-06-26 11:18:18,686 - embeddings.store_embeddings - INFO - Clean up tablecolumn_details_embeddings: column_query_string="DELETE FROM `uk-bh-experiments-argolis.opendataqna.tablecolumn_details_embeddings` WHERE table_schema = 'breedr' AND table_name IN( 'business_units','cts_dairy_breeds','unit_of_measurement_business_unit','supply_chain','medicine_vmd_data','animals_identifierassignment','animal_types','medicine_lineitem','predictions_when_weighed','countries','animals_tag_change','lots','animals_identifierpreferences','kill_information','animals','animals_tag_value','currencies','medicine_stockitem_species','medicine_withdrawals','crush_app_sessions','activity_types','animals2','groups','pasture_types','business_unit_users','animals_tag','organizations_organisation','medicine_itemtransaction','medicine_stockitem','medicines','offers','supply_chain_member','group_reports','activities','animals_animal_breeds','reports_business_types','business_types','animal_breeds','alert_type','fields','activity_templates','account_user','crush_app_sessions_animals','fields_pasture_types','weights') "
# 2024-06-26 11:18:21,545 - embeddings.store_embeddings - INFO - Storing column embeddings to BQ uk-bh-experiments-argolis.opendataqna.tablecolumn_details_embeddings
# Table and Column embeddings are saved to vector store

# %% [markdown]
# ### 🗄️ **Load Known Good SQL into Vector Store**
# Known Good Queries are used to create query cache for Few shot examples. Creating a query cache is highly recommended for best outcomes!
#
# The following cell will load the Natural Language Question and Known Good SQL pairs into our Vector Store. There pairs are loaded from `known_good_sql.csv` file inside scripts folder. If you have your own Question-SQL examples, curate them in .csv file before running the cell below.
#
# If no Known Good Queries are available at this time to create query cache, you can use [3_LoadKnownGoodSQL.ipynb](3_LoadKnownGoodSQL.ipynb) to load them later.

# %% [markdown]
# #### Format of the Known Good SQL File (known_good_sql.csv)
#
# prompt | sql | database_name [3 columns]
#
# prompt ==> User Question
#
# sql ==> SQL for the user question (Note that the sql should enclosed in quotes and only in single line. Please remove the line  break)
#
# database_name ==>This name should exactly  match the SCHEMA   NAME for Postgres Source or BQ_DATASET_NAME

# %%
from env_setup import create_kgq_sql_table, store_kgq_sql_embeddings

# Create table for known good queries (if enabled)
await(create_kgq_sql_table()) 

# Store known good query embeddings (if enabled)
await(store_kgq_sql_embeddings())
# Out:
# Creating kgq table in vector store.
# Reading contents of known_good_sql.csv
# Known Good SQL Found at Path :: /home/jupyter/uk-bh-experiments/bhfork-opendataqna/applied-ai-engineering-samples/scripts/known_good_sql.csv
# Storing kgq embeddings in vector store table.
# kgq embeddings stored.

# %% [markdown]
# ### 🥁 If all the above steps are executed successfully, the following should be set up:
#
# * GCP project and all the required IAM permissions
#
# * Environment to run the solution
#
# * Data source and Vector store for the solution

# %% [markdown]
# __________________________________________________________________________________________________________________
